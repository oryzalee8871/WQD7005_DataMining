# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install quandl
# https://blog.quandl.com/api-for-futures-data
import quandl

# Sign up here for key https://www.quandl.com/?modal=register
key='PLEASE USE YOUR OWN KEY'
quandl.ApiConfig.api_key = key

# %%
data = quandl.get("CHRIS/CME_CPO1", start_date="2000-12-31", end_date="2020-02-23")

# %%
data.tail(30)
# Out:
#             Open  High  Low  Last  Change  Settle  Volume  \
# Date
# 2020-01-09   NaN   NaN  NaN   NaN   15.50  757.75     0.0
# 2020-01-10   NaN   NaN  NaN   NaN    5.25  763.00     0.0
# 2020-01-13   NaN   NaN  NaN   NaN    4.75  758.25     0.0
# 2020-01-14   NaN   NaN  NaN   NaN   12.50  745.75     0.0
# 2020-01-15   NaN   NaN  NaN   NaN   10.50  735.25     0.0
# 2020-01-16   NaN   NaN  NaN   NaN    6.50  728.75     0.0
# 2020-01-17   NaN   NaN  NaN   NaN    5.50  723.25     0.0
# 2020-01-21   NaN   NaN  NaN   NaN    2.25  728.50     0.0
# 2020-01-22   NaN   NaN  NaN   NaN    6.75  735.25     0.0
# 2020-01-23   NaN   NaN  NaN   NaN    3.00  732.25     0.0
# 2020-01-24   NaN   NaN  NaN   NaN    3.75  728.50     0.0
# 2020-01-27   NaN   NaN  NaN   NaN     NaN  728.50     0.0
# 2020-01-28   NaN   NaN  NaN   NaN   14.00  714.50     0.0
# 2020-01-29   NaN   NaN  NaN   NaN    5.50  720.00     0.0
# 2020-01-30   NaN   NaN  NaN   NaN    2.00  718.00     0.0
# ...

# %%
data.to_csv('CPO_price.csv')

# %%
data['Settle'].plot()
